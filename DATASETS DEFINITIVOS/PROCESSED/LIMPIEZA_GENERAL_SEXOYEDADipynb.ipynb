# %%
#imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

url_df_all = "https://raw.githubusercontent.com/AngelaBurgaleta/TFM_NHANES/main/DATASETS%20DEFINITIVOS/RAW/df_raw.csv"


df = pd.read_csv(url_df_all)
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.isna().sum()
# Out:
# SEQN               0
# DIQ010             0
# DIQ070             0
# INQ020             0
# INDFMMPI           0
# INDFMMPC           0
# BPXSY1             0
# BPXDI1             0
# BMXWT              0
# BMXHT              0
# BMXBMI             0
# BMXWAIST           0
# BPQ030             0
# BPQ040A            0
# BPQ050A            0
# BPQ090D            0
# LBXGLU             0
# LBXIN              0
# MCQ010             0
# MCQ080             0
# MCQ220             0
# MCQ300C            0
# HIQ011             0
# LBDHDD             0
# SMQ020             0
# LBXTR              0
# RIAGENDR           0
# RIDAGEYR           0
# RIDRETH3           0
# DMDEDUC2           0
# PAQ605             0
# PAQ620             0
# PAQ635             0
# PAQ650             0
# PAQ665             0
# HSD010             0
# ALQ130             0
# DBQ700             0
# SLQ050             0
# DPQ020             0
# DPQ030             0
# DPQ040             0
# DPQ050             0
# RIDAGEYR_Tramos    0
# WHI                0
# ALQ130_Tramos      0
# dtype: int64

# %%
#GRUPOS POR EDAD
df['RIDAGEYR'].describe()

df.loc[(df['RIDAGEYR'] <= 5) & (df['RIDAGEYR'] >= 1), 'RIDAGEYR_Tramos'] = int(1)
df.loc[(df['RIDAGEYR'] <= 12) & (df['RIDAGEYR'] >= 5), 'RIDAGEYR_Tramos'] = int(2)
df.loc[(df['RIDAGEYR'] <= 20) & (df['RIDAGEYR'] > 12), 'RIDAGEYR_Tramos'] = int(3)
df.loc[(df['RIDAGEYR'] <= 35) & (df['RIDAGEYR'] > 20), 'RIDAGEYR_Tramos'] = int(4)
df.loc[(df['RIDAGEYR'] <= 50) & (df['RIDAGEYR'] > 35), 'RIDAGEYR_Tramos'] = int(5)
df.loc[(df['RIDAGEYR'] <= 65) & (df['RIDAGEYR'] > 50), 'RIDAGEYR_Tramos'] = int(6)
df.loc[(df['RIDAGEYR'] <= 80) & (df['RIDAGEYR'] > 65), 'RIDAGEYR_Tramos'] = int(7)

#dataset por male y female
df_male = df[df['RIAGENDR']==1]
df_female = df[df['RIAGENDR']==2]

# %% [markdown]
# #PRINTEAR VALORES PARA LA LIMPIEZA

# %%
#BMXWT
print("male1 mode: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 1].mode())
print("male2 mode: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 2].mode())
print("male3 mode: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 3].mode())
print("male4 mode: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 4].mode())
print("male5 mode: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 5].mode())
print("male6 mode: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 6].mode())
print("male7 mode : ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 7].mode())

print("female1 mode: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 1].mode())
print("female2 mode: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 2].mode())
print("female3 mode: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 3].mode())
print("female4 mode: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 4].mode())
print("female5 mode: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 5].mode())
print("female6 mode: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 6].mode())
print("female7 mode : ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 7].mode())

print("male1 median: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 1].median())
print("male2 median: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 2].median())
print("male3 median: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 3].median())
print("male4 median: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 4].median())
print("male5 median: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 5].median())
print("male6 median: ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 6].median())
print("male7 median : ", df_male['BMXWT'][df['RIDAGEYR_Tramos'] == 7].median())

print("female1 median: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 1].median())
print("female2 median: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 2].median())
print("female3 median: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 3].median())
print("female4 median: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 4].median())
print("female5 median: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 5].median())
print("female6 median: ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 6].median())
print("female7 median : ", df_female['BMXWT'][df['RIDAGEYR_Tramos'] == 7].median())
# Out:
# male1 mode:  0    14.3
# dtype: float64
# male2 mode:  0    27.2
# dtype: float64
# male3 mode:  0    63.5
# dtype: float64
# male4 mode:  0    82.8
# dtype: float64
# male5 mode:  0    88.0
# dtype: float64
# male6 mode:  0    78.7
# 1    82.6
# dtype: float64
# male7 mode :  0    78.5
# dtype: float64
# female1 mode:  0    14.6
# dtype: float64
# female2 mode:  0    19.6
# dtype: float64
# female3 mode:  0    49.9
# dtype: float64
# female4 mode:  0    59.5
# 1    60.3
# 2    62.4
# 3    63.7
# 4    68.4
# 5    68.9
# dtype: float64
# female5 mode:  0    62.8
# 1    74.5
# dtype: float64
# female6 mode:  0    65.3
# dtype: float64
# female7 mode :  0    66.3
# dtype: float64
# male1 median:  14.6
# male2 median:  31.2
# male3 median:  68.1
# male4 median:  82.8
# male5 median:  86.6
# male6 median:  84.0
# male7 median :  81.15
# female1 median:  14.1
# female2 median:  32.3
# female3 median:  60.1
# female4 median:  70.8
# female5 median:  75.0
# female6 median:  74.9
# female7 median :  70.1

# %%
#BMXHT
print("male1 mode: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 1].mode())
print("male2 mode: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 2].mode())
print("male3 mode: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 3].mode())
print("male4 mode: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 4].mode())
print("male5 mode: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 5].mode())
print("male6 mode: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 6].mode())
print("male7 mode : ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 7].mode())

print("female1 mode: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 1].mode())
print("female2 mode: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 2].mode())
print("female3 mode: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 3].mode())
print("female4 mode: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 4].mode())
print("female5 mode: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 5].mode())
print("female6 mode: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 6].mode())
print("female7 mode : ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 7].mode())

print("male1 median: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 1].median())
print("male2 median: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 2].median())
print("male3 median: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 3].median())
print("male4 median: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 4].median())
print("male5 median: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 5].median())
print("male6 median: ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 6].median())
print("male7 median : ", df_male['BMXHT'][df['RIDAGEYR_Tramos'] == 7].median())

print("female1 median: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 1].median())
print("female2 median: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 2].median())
print("female3 median: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 3].median())
print("female4 median: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 4].median())
print("female5 median: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 5].median())
print("female6 median: ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 6].median())
print("female7 median : ", df_female['BMXHT'][df['RIDAGEYR_Tramos'] == 7].median())
# Out:
# male1 mode:  0    102.8
# dtype: float64
# male2 mode:  0    126.6
# 1    127.9
# dtype: float64
# male3 mode:  0    168.7
# dtype: float64
# male4 mode:  0    178.7
# dtype: float64
# male5 mode:  0    171.6
# dtype: float64
# male6 mode:  0    172.9
# dtype: float64
# male7 mode :  0    168.4
# dtype: float64
# female1 mode:  0    89.3
# dtype: float64
# female2 mode:  0    123.0
# 1    123.1
# 2    139.6
# dtype: float64
# female3 mode:  0    161.4
# dtype: float64
# female4 mode:  0    160.3
# 1    160.8
# 2    163.0
# dtype: float64
# female5 mode:  0    165.5
# dtype: float64
# female6 mode:  0    161.8
# dtype: float64
# female7 mode :  0    160.2
# dtype: float64
# male1 median:  99.0
# male2 median:  133.4
# male3 median:  172.0
# male4 median:  175.4
# male5 median:  174.6
# male6 median:  173.1
# male7 median :  171.2
# female1 median:  97.05
# female2 median:  133.7
# female3 median:  160.8
# female4 median:  161.7
# female5 median:  161.45
# female6 median:  159.7
# female7 median :  156.8

# %%
99#BMXBMI
print("male1 mode: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 1].mode())
print("male2 mode: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 2].mode())
print("male3 mode: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 3].mode())
print("male4 mode: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 4].mode())
print("male5 mode: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 5].mode())
print("male6 mode: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 6].mode())
print("male7 mode : ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 7].mode())

print("female1 mode: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 1].mode())
print("female2 mode: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 2].mode())
print("female3 mode: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 3].mode())
print("female4 mode: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 4].mode())
print("female5 mode: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 5].mode())
print("female6 mode: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 6].mode())
print("female7 mode : ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 7].mode())

print("male1 median: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 1].median())
print("male2 median: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 2].median())
print("male3 median: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 3].median())
print("male4 median: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 4].median())
print("male5 median: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 5].median())
print("male6 median: ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 6].median())
print("male7 median : ", df_male['BMXBMI'][df['RIDAGEYR_Tramos'] == 7].median())

print("female1 median: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 1].median())
print("female2 median: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 2].median())
print("female3 median: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 3].median())
print("female4 median: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 4].median())
print("female5 median: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 5].median())
print("female6 median: ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 6].median())
print("female7 median : ", df_female['BMXBMI'][df['RIDAGEYR_Tramos'] == 7].median())
# Out:
# male1 mode:  0    16.1
# dtype: float64
# male2 mode:  0    16.2
# dtype: float64
# male3 mode:  0    22.0
# dtype: float64
# male4 mode:  0    25.1
# dtype: float64
# male5 mode:  0    26.5
# 1    27.1
# dtype: float64
# male6 mode:  0    26.6
# dtype: float64
# male7 mode :  0    26.7
# dtype: float64
# female1 mode:  0    15.5
# dtype: float64
# female2 mode:  0    15.9
# 1    16.7
# dtype: float64
# female3 mode:  0    20.0
# dtype: float64
# female4 mode:  0    22.5
# dtype: float64
# female5 mode:  0    27.3
# 1    28.7
# dtype: float64
# female6 mode:  0    28.9
# dtype: float64
# female7 mode :  0    29.4
# dtype: float64
# male1 median:  16.2
# male2 median:  17.25
# male3 median:  23.0
# male4 median:  27.0
# male5 median:  28.4
# male6 median:  28.1
# male7 median :  27.65
# female1 median:  16.1
# female2 median:  17.8
# female3 median:  23.2
# female4 median:  27.2
# female5 median:  29.05
# female6 median:  29.4
# female7 median :  28.5

# %%
#BMXWAIST
print("male1 mode: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 1].mode())
print("male2 mode: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 2].mode())
print("male3 mode: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 3].mode())
print("male4 mode: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 4].mode())
print("male5 mode: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 5].mode())
print("male6 mode: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 6].mode())
print("male7 mode : ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 7].mode())

print("female1 mode: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 1].mode())
print("female2 mode: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 2].mode())
print("female3 mode: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 3].mode())
print("female4 mode: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 4].mode())
print("female5 mode: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 5].mode())
print("female6 mode: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 6].mode())
print("female7 mode : ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 7].mode())

print("male1 median: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 1].median())
print("male2 median: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 2].median())
print("male3 median: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 3].median())
print("male4 median: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 4].median())
print("male5 median: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 5].median())
print("male6 median: ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 6].median())
print("male7 median : ", df_male['BMXWAIST'][df['RIDAGEYR_Tramos'] == 7].median())

print("female1 median: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 1].median())
print("female2 median: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 2].median())
print("female3 median: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 3].median())
print("female4 median: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 4].median())
print("female5 median: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 5].median())
print("female6 median: ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 6].median())
print("female7 median : ", df_female['BMXWAIST'][df['RIDAGEYR_Tramos'] == 7].median())
# Out:
# male1 mode:  0    49.5
# dtype: float64
# male2 mode:  0    53.0
# 1    57.0
# dtype: float64
# male3 mode:  0    76.0
# dtype: float64
# male4 mode:  0    84.5
# 1    97.0
# dtype: float64
# male5 mode:  0    94.5
# dtype: float64
# male6 mode:  0    95.0
# 1    97.5
# dtype: float64
# male7 mode :  0    98.5
# dtype: float64
# female1 mode:  0    51.0
# dtype: float64
# female2 mode:  0    57.0
# dtype: float64
# female3 mode:  0    70.0
# dtype: float64
# female4 mode:  0    78.0
# 1    82.1
# 2    83.2
# 3    89.0
# dtype: float64
# female5 mode:  0    88.5
# dtype: float64
# female6 mode:  0    94.0
# dtype: float64
# female7 mode :  0    97.0
# dtype: float64
# male1 median:  50.0
# male2 median:  60.7
# male3 median:  79.5
# male4 median:  93.3
# male5 median:  100.0
# male6 median:  101.5
# male7 median :  103.7
# female1 median:  49.7
# female2 median:  62.6
# female3 median:  79.2
# female4 median:  91.2
# female5 median:  96.4
# female6 median:  99.2
# female7 median :  99.2

# %%
#LBXGLU
print("male1 mode: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 1].mode())
print("male2 mode: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 2].mode())
print("male3 mode: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 3].mode())
print("male4 mode: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 4].mode())
print("male5 mode: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 5].mode())
print("male6 mode: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 6].mode())
print("male7 mode : ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 7].mode())

print("female1 mode: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 1].mode())
print("female2 mode: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 2].mode())
print("female3 mode: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 3].mode())
print("female4 mode: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 4].mode())
print("female5 mode: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 5].mode())
print("female6 mode: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 6].mode())
print("female7 mode : ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 7].mode())

print("male1 median: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 1].median())
print("male2 median: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 2].median())
print("male3 median: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 3].median())
print("male4 median: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 4].median())
print("male5 median: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 5].median())
print("male6 median: ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 6].median())
print("male7 median : ", df_male['LBXGLU'][df['RIDAGEYR_Tramos'] == 7].median())

print("female1 median: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 1].median())
print("female2 median: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 2].median())
print("female3 median: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 3].median())
print("female4 median: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 4].median())
print("female5 median: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 5].median())
print("female6 median: ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 6].median())
print("female7 median : ", df_female['LBXGLU'][df['RIDAGEYR_Tramos'] == 7].median())
# Out:
# male1 mode:  Series([], dtype: float64)
# male2 mode:  0    96.0
# dtype: float64
# male3 mode:  0    99.0
# dtype: float64
# male4 mode:  0    99.0
# dtype: float64
# male5 mode:  0    101.0
# dtype: float64
# male6 mode:  0    106.0
# dtype: float64
# male7 mode :  0    105.0
# dtype: float64
# female1 mode:  Series([], dtype: float64)
# female2 mode:  0    95.0
# 1    96.0
# dtype: float64
# female3 mode:  0    89.0
# 1    93.0
# dtype: float64
# female4 mode:  0    92.0
# dtype: float64
# female5 mode:  0    96.0
# dtype: float64
# female6 mode:  0    102.0
# dtype: float64
# female7 mode :  0    97.0
# dtype: float64
# male1 median:  nan
# male2 median:  96.0
# male3 median:  97.0
# male4 median:  98.0
# male5 median:  102.0
# male6 median:  107.0
# male7 median :  111.0
# female1 median:  nan
# female2 median:  95.0
# female3 median:  93.0
# female4 median:  94.0
# female5 median:  97.0
# female6 median:  103.0
# female7 median :  106.0

# %%
#LBXIN
print("male1 mode: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 1].mode())
print("male2 mode: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 2].mode())
print("male3 mode: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 3].mode())
print("male4 mode: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 4].mode())
print("male5 mode: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 5].mode())
print("male6 mode: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 6].mode())
print("male7 mode : ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 7].mode())

print("female1 mode: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 1].mode())
print("female2 mode: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 2].mode())
print("female3 mode: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 3].mode())
print("female4 mode: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 4].mode())
print("female5 mode: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 5].mode())
print("female6 mode: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 6].mode())
print("female7 mode : ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 7].mode())

print("male1 median: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 1].median())
print("male2 median: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 2].median())
print("male3 median: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 3].median())
print("male4 median: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 4].median())
print("male5 median: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 5].median())
print("male6 median: ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 6].median())
print("male7 median : ", df_male['LBXIN'][df['RIDAGEYR_Tramos'] == 7].median())

print("female1 median: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 1].median())
print("female2 median: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 2].median())
print("female3 median: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 3].median())
print("female4 median: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 4].median())
print("female5 median: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 5].median())
print("female6 median: ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 6].median())
print("female7 median : ", df_female['LBXIN'][df['RIDAGEYR_Tramos'] == 7].median())
# Out:
# male1 mode:  Series([], dtype: float64)
# male2 mode:  0     5.24
# 1     6.19
# 2     8.17
# 3    10.86
# dtype: float64
# male3 mode:  0    6.61
# dtype: float64
# male4 mode:  0    6.21
# dtype: float64
# male5 mode:  0    4.83
# 1    5.04
# 2    6.06
# 3    7.63
# 4    8.65
# dtype: float64
# male6 mode:  0     2.74
# 1     5.58
# 2     6.55
# 3     9.04
# 4    11.24
# dtype: float64
# male7 mode :  0    0.71
# dtype: float64
# female1 mode:  Series([], dtype: float64)
# female2 mode:  0     6.17
# 1    14.67
# 2    20.67
# dtype: float64
# female3 mode:  0    7.72
# dtype: float64
# female4 mode:  0    6.47
# dtype: float64
# female5 mode:  0    6.75
# dtype: float64
# female6 mode:  0      4.71
# 1      5.08
# 2      5.71
# 3      5.80
# 4      5.92
# 5      6.75
# 6      6.82
# 7      8.22
# 8      9.13
# 9     10.08
# 10    10.28
# 11    10.80
# dtype: float64
# female7 mode :  0     5.91
# 1     5.93
# 2     6.67
# 3     8.05
# 4     8.85
# 5    11.32
# dtype: float64
# male1 median:  nan
# male2 median:  9.1
# male3 median:  9.77
# male4 median:  8.8
# male5 median:  9.99
# male6 median:  10.04
# male7 median :  9.89
# female1 median:  nan
# female2 median:  14.295
# female3 median:  11.49
# female4 median:  9.55
# female5 median:  9.27
# female6 median:  10.445
# female7 median :  9.98

# %%
#LBDHDD
print("male1 mode: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 1].mode())
print("male2 mode: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 2].mode())
print("male3 mode: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 3].mode())
print("male4 mode: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 4].mode())
print("male5 mode: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 5].mode())
print("male6 mode: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 6].mode())
print("male7 mode : ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 7].mode())

print("female1 mode: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 1].mode())
print("female2 mode: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 2].mode())
print("female3 mode: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 3].mode())
print("female4 mode: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 4].mode())
print("female5 mode: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 5].mode())
print("female6 mode: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 6].mode())
print("female7 mode : ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 7].mode())

print("male1 median: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 1].median())
print("male2 median: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 2].median())
print("male3 median: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 3].median())
print("male4 median: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 4].median())
print("male5 median: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 5].median())
print("male6 median: ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 6].median())
print("male7 median : ", df_male['LBDHDD'][df['RIDAGEYR_Tramos'] == 7].median())

print("female1 median: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 1].median())
print("female2 median: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 2].median())
print("female3 median: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 3].median())
print("female4 median: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 4].median())
print("female5 median: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 5].median())
print("female6 median: ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 6].median())
print("female7 median : ", df_female['LBDHDD'][df['RIDAGEYR_Tramos'] == 7].median())
# Out:
# male1 mode:  Series([], dtype: float64)
# male2 mode:  0    51.0
# 1    54.0
# dtype: float64
# male3 mode:  0    49.0
# dtype: float64
# male4 mode:  0    41.0
# dtype: float64
# male5 mode:  0    41.0
# dtype: float64
# male6 mode:  0    41.0
# dtype: float64
# male7 mode :  0    41.0
# dtype: float64
# female1 mode:  Series([], dtype: float64)
# female2 mode:  0    54.0
# dtype: float64
# female3 mode:  0    48.0
# dtype: float64
# female4 mode:  0    48.0
# dtype: float64
# female5 mode:  0    48.0
# dtype: float64
# female6 mode:  0    48.0
# dtype: float64
# female7 mode :  0    54.0
# dtype: float64
# male1 median:  nan
# male2 median:  56.0
# male3 median:  49.0
# male4 median:  46.0
# male5 median:  45.0
# male6 median:  46.0
# male7 median :  47.0
# female1 median:  nan
# female2 median:  53.0
# female3 median:  53.0
# female4 median:  55.0
# female5 median:  54.0
# female6 median:  56.0
# female7 median :  57.0

# %% [markdown]
# #aux

# %%
#dataset por male y female
df_male = df[df['RIAGENDR']==1]
df_female = df[df['RIAGENDR']==2]
print("moda cintura mujeres: ", df_female['LBDHDD'].mode())
print("moda cintura hombres: ", df_male['LBDHDD'].mode())
print("moda altura mujeres: ", df_female['BMXWAIST'].median())
print("moda altura hombres: ", df_male['BMXWAIST'].median())

# %%
#BMXWT
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)].mode()
#df['LBDHDD'][df['RIAGENDR'] == 1] = df['LBDHDD'].fillna(48)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# #LIMPIEZA POR SEXO Y EDAD

# %%
#LIMPIEZA DE TODOS LOS CAMPOS FINALIZADA 
#Limpieza DIQ010: el doctor te ha dicho que tienes diabetes (0 no 1 si 2 borderline)
df['DIQ010'] = df['DIQ010'].fillna(0)
df['DIQ010'] = df.DIQ010.replace({9: 0})
df['DIQ010'] = df.DIQ010.replace({7: 0})
df['DIQ010'] = df.DIQ010.replace({2: 0})
df['DIQ010'] = df.DIQ010.replace({3: 2})

#--------------------------------------REQ5 SM
#DIQ070: pastillas para glucosa elevada  0 no 1 si (REQ5)
df['DIQ070'] = df['DIQ070'].fillna(2)
df['DIQ070'] = df.DIQ070.replace({9: 2})
df['DIQ070'] = df.DIQ070.replace({7: 2})
#--------------------------------------REQ5 SM

#INQ020: ingresos salariales en casa
df['INQ020'] = df['INQ020'].fillna(1)
df['INQ020'] = df.INQ020.replace({9: 0})
df['INQ020'] = df.INQ020.replace({7: 0})
df['INQ020'] = df.INQ020.replace({2: 0})

#INDFMMPI: limpieza indice de pobreza de 0 a 4.99 y 5 para 5  o má. 
#Se rellenan los valores con la media 2.1
df['INDFMMPI'] = df['INDFMMPI'].fillna(2.1)
df['INDFMMPI'] = df.INDFMMPI.replace({5.397605e-79: 0})

#INDFMMPC: limpieza cat pobreza con la moda 3
df['INDFMMPC'] = df.INDFMMPC.replace({7: 3})
df['INDFMMPC'] = df.INDFMMPC.replace({9: 3})
df['INDFMMPC'] = df['INDFMMPC'].fillna(3)

#BPXSY1 moda 116
df['BPXSY1']= df['BPXSY1'].fillna(116)

#BPXDI1 moda 68
df['BPXDI1']= df['BPXDI1'].fillna(68)

#BMXWT mediana peso 72.3 en hombres y 62.8 en mujeres CAMBIAR
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)]= df['BMXWT'].fillna(14.6)
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 2)]= df['BMXWT'].fillna(14.1)

df['BMXWT'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 1)]= df['BMXWT'].fillna(31.2)
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 2)]= df['BMXWT'].fillna(32.3)

df['BMXWT'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 1)]= df['BMXWT'].fillna(68.1)
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 2)]= df['BMXWT'].fillna(60.1)

df['BMXWT'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 1)]= df['BMXWT'].fillna(82.8)
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 2)]= df['BMXWT'].fillna(70.8)

df['BMXWT'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 1)]= df['BMXWT'].fillna(86.8)
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 2)]= df['BMXWT'].fillna(75)

df['BMXWT'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 1)]= df['BMXWT'].fillna(84)
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 2)]= df['BMXWT'].fillna(74.9)

df['BMXWT'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 1)]= df['BMXWT'].fillna(81)
df['BMXWT'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 2)]= df['BMXWT'].fillna(70.1)


#BMXHT mediana altura 169.8 en hombres y 157.4 en mujeres CAMBIAR
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)]= df['BMXHT'].fillna(99)
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 2)]= df['BMXHT'].fillna(97.05)

df['BMXHT'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 1)]= df['BMXHT'].fillna(133.4)
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 2)]= df['BMXHT'].fillna(133.7)

df['BMXHT'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 1)]= df['BMXHT'].fillna(172)
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 2)]= df['BMXHT'].fillna(160.8)

df['BMXHT'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 1)]= df['BMXHT'].fillna(175.4)
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 2)]= df['BMXHT'].fillna(161.7)

df['BMXHT'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 1)]= df['BMXHT'].fillna(174.6)
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 2)]= df['BMXHT'].fillna(161.45)

df['BMXHT'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 1)]= df['BMXHT'].fillna(173.1)
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 2)]= df['BMXHT'].fillna(159.7)

df['BMXHT'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 1)]= df['BMXHT'].fillna(171.2)
df['BMXHT'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 2)]= df['BMXHT'].fillna(156.8)

#BMXBMI: moda CAMBIAR
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)]= df['BMXBMI'].fillna(16.2)
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 2)]= df['BMXBMI'].fillna(16.2)

df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 1)]= df['BMXBMI'].fillna(17.25)
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 2)]= df['BMXBMI'].fillna(17.8)

df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 1)]= df['BMXBMI'].fillna(23)
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 2)]= df['BMXBMI'].fillna(23.2)

df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 1)]= df['BMXBMI'].fillna(27)
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 2)]= df['BMXBMI'].fillna(27.2)

df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 1)]= df['BMXBMI'].fillna(28.4)
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 2)]= df['BMXBMI'].fillna(29.05)

df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 1)]= df['BMXBMI'].fillna(28.1)
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 2)]= df['BMXBMI'].fillna(29.4)

df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 1)]= df['BMXBMI'].fillna(27.65)
df['BMXBMI'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 2)]= df['BMXBMI'].fillna(28.5)

#BMXWAIST: moediana CAMBIAR
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)]= df['BMXWAIST'].fillna(50)
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 2)]= df['BMXWAIST'].fillna(49.7)

df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 1)]= df['BMXWAIST'].fillna(60.7)
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 2)]= df['BMXWAIST'].fillna(62.7)

df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 1)]= df['BMXWAIST'].fillna(79.5)
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 2)]= df['BMXWAIST'].fillna(79.2)

df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 1)]= df['BMXWAIST'].fillna(93.3)
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 2)]= df['BMXWAIST'].fillna(91.2)

df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 1)]= df['BMXWAIST'].fillna(100)
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 2)]= df['BMXWAIST'].fillna(96.4)

df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 1)]= df['BMXWAIST'].fillna(101.5)
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 2)]= df['BMXWAIST'].fillna(99.4)

df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 1)]= df['BMXWAIST'].fillna(103.7)
df['BMXWAIST'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 2)]= df['BMXWAIST'].fillna(99.2)




#waist height index---------
df.loc[:, 'WHI'] = df['BMXWAIST'] / df['BMXHT']
df['WHI'].isna().sum()
#--------------------

#BPQ030 te han dicho que tienes la presión sanguinea alta más de dos veces
df['BPQ030'] = df['BPQ030'].fillna(0)
df['BPQ030'] = df.BPQ030.replace({2: 0})
df['BPQ030'] = df.BPQ030.replace({7: 0})
df['BPQ030'] = df.BPQ030.replace({9: 0})

#---------------------------------------------------------------
#BPQ040A tomar pastillas para el colesterol HDL bajo (req3 MS)
df['BPQ040A']= df['BPQ040A'].fillna(2)
df['BPQ040A'] = df.BPQ040A.replace({9: 2})

#BPQ050A tomar pastillas para la presión sanguinea elevada (req4 MS)
df['BPQ050A']= df['BPQ050A'].fillna(2)
df['BPQ050A'] = df.BPQ050A.replace({9: 2})

#BPQ090D tomar medicamentos para el colesterol elevado (REQ2 ms)
df['BPQ090D'] = df['BPQ090D'].fillna(2)
df['BPQ090D'] = df.BPQ090D.replace({9: 2})
#--------------------------------------------------------------

#LBXGLU: glucosa en ayunas elevada, se rellena con la moda CAMBIAR
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)]= df['LBXGLU'].fillna(90)
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 2)]= df['LBXGLU'].fillna(90)

df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 1)]= df['LBXGLU'].fillna(96)
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 2)]= df['LBXGLU'].fillna(95)

df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 1)]= df['LBXGLU'].fillna(97)
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 2)]= df['LBXGLU'].fillna(93)

df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 1)]= df['LBXGLU'].fillna(98)
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 2)]= df['LBXGLU'].fillna(94)

df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 1)]= df['LBXGLU'].fillna(102)
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 2)]= df['LBXGLU'].fillna(97)

df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 1)]= df['LBXGLU'].fillna(107)
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 2)]= df['LBXGLU'].fillna(103)

df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 1)]= df['LBXGLU'].fillna(111)
df['LBXGLU'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 2)]= df['LBXGLU'].fillna(106)

#LBXIN: insulina en uU/mL moda CAMBIAR
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)]= df['LBXIN'].fillna(5.24)
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 2)]= df['LBXIN'].fillna(6.17)

df['LBXIN'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 1)]= df['LBXIN'].fillna(9.1)
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 2)]= df['LBXIN'].fillna(9.89)

df['LBXIN'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 1)]= df['LBXIN'].fillna(9.77)
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 2)]= df['LBXIN'].fillna(11.49)

df['LBXIN'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 1)]= df['LBXIN'].fillna(8.8)
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 2)]= df['LBXIN'].fillna(9.55)

df['LBXIN'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 1)]= df['LBXIN'].fillna(9.99)
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 2)]= df['LBXIN'].fillna(9.27)

df['LBXIN'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 1)]= df['LBXIN'].fillna(10.04)
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 2)]= df['LBXIN'].fillna(10.445)

df['LBXIN'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 1)]= df['LBXIN'].fillna(9.89)
df['LBXIN'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 2)]= df['LBXIN'].fillna(9.98)

#MCQ010: el doctor dice que tienes sobrepeso      
df['MCQ010'] = df['MCQ010'].fillna(0)
df['MCQ010'] = df.MCQ010.replace({9: 0})
df['MCQ010'] = df.MCQ010.replace({7: 0})
df['MCQ010'] = df.MCQ010.replace({2: 0})

#MCQ080: el doctor dice que tienes asma     
df['MCQ080'] = df['MCQ080'].fillna(0)
df['MCQ080'] = df.MCQ080.replace({9: 0})
df['MCQ080'] = df.MCQ080.replace({7: 0})
df['MCQ080'] = df.MCQ080.replace({2: 0})

#MCQ220: el doctor dice que tienes cancer alguna vez      
df['MCQ220'] = df['MCQ220'].fillna(0)
df['MCQ220'] = df.MCQ220.replace({9: 0})
df['MCQ220'] = df.MCQ220.replace({7: 0})
df['MCQ220'] = df.MCQ220.replace({2: 0})

#MCQ300C: cerca relativamente a tener diabetes 
df['MCQ300C'] = df['MCQ300C'].fillna(0)
df['MCQ300C'] = df.MCQ300C.replace({9: 0})
df['MCQ300C'] = df.MCQ300C.replace({7: 0})
df['MCQ300C'] = df.MCQ300C.replace({2: 0})

#HIQ011: seguro sanitario   
df['HIQ011'] = df.HIQ011.replace({9: 1})
df['HIQ011'] = df.HIQ011.replace({7: 1})
df['HIQ011'] = df.HIQ011.replace({2: 0})


#LBDHDD: colesterol hdl diferente en mujeres y hombres moda 55 para mujeres y 48 en hombres CAMBIAR
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 1)]= df['LBDHDD'].fillna(56)
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==1) & (df['RIAGENDR'] == 2)]= df['LBDHDD'].fillna(53)

df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 1)]= df['LBDHDD'].fillna(56)
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==2) & (df['RIAGENDR'] == 2)]= df['LBDHDD'].fillna(53)

df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 1)]= df['LBDHDD'].fillna(49)
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==3) & (df['RIAGENDR'] == 2)]= df['LBDHDD'].fillna(53)

df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 1)]= df['LBDHDD'].fillna(46)
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==4) & (df['RIAGENDR'] == 2)]= df['LBDHDD'].fillna(53)

df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 1)]= df['LBDHDD'].fillna(45)
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==5) & (df['RIAGENDR'] == 2)]= df['LBDHDD'].fillna(54)

df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 1)]= df['LBDHDD'].fillna(46)
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==6) & (df['RIAGENDR'] == 2)]= df['LBDHDD'].fillna(56)

df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 1)]= df['LBDHDD'].fillna(47)
df['LBDHDD'][(df['RIDAGEYR_Tramos'] ==7) & (df['RIAGENDR'] == 2)]= df['LBDHDD'].fillna(57)


#SMQ020:ha fumado 100 cigarrillos en su vida    
df['SMQ020'] = df['SMQ020'].fillna(0)
df['SMQ020'] = df.SMQ020.replace({9: 0})
df['SMQ020'] = df.SMQ020.replace({7: 0})
df['SMQ020'] = df.SMQ020.replace({2: 0})


#LBXTR: 89 es la mediana y es el nivel de trigliceridos CAMBIAR
df['LBXTR']= df['LBXTR'].fillna(89)

#DMDEDUC2: nivel educativo se trunca a some college CAMBIAR
df['DMDEDUC2'] = df.DMDEDUC2.replace({7: 4})
df['DMDEDUC2'] = df.DMDEDUC2.replace({9: 4})
df['DMDEDUC2'] = df['DMDEDUC2'].fillna(4)

#PAQ605
df['PAQ605'] = df['PAQ605'].fillna(0)
df['PAQ605'] = df.PAQ605.replace({9: 0})
df['PAQ605'] = df.PAQ605.replace({7: 0})
df['PAQ605'] = df.PAQ605.replace({2: 0})

#PAQ620     
df['PAQ620'] = df['PAQ620'].fillna(0)
df['PAQ620'] = df.PAQ620.replace({9: 0})
df['PAQ620'] = df.PAQ620.replace({7: 0})
df['PAQ620'] = df.PAQ620.replace({2: 0})

#PAQ635    
df['PAQ635'] = df['PAQ635'].fillna(0)
df['PAQ635'] = df.PAQ635.replace({9: 0})
df['PAQ635'] = df.PAQ635.replace({7: 0})
df['PAQ635'] = df.PAQ635.replace({2: 0})

#PAQ650   
df['PAQ650'] = df['PAQ650'].fillna(0)
df['PAQ650'] = df.PAQ650.replace({9: 0})
df['PAQ650'] = df.PAQ650.replace({7: 0})
df['PAQ650'] = df.PAQ650.replace({2: 0})

#PAQ665      
df['PAQ665'] = df['PAQ665'].fillna(0)
df['PAQ665'] = df.PAQ665.replace({9: 0})
df['PAQ665'] = df.PAQ665.replace({7: 0})
df['PAQ665'] = df.PAQ665.replace({2: 0})

#HSD010: salud del paciente se rellena con buena 3
df['HSD010'] = df['HSD010'].fillna(3)
df['HSD010'] = df.HSD010.replace({9: 3})
df['HSD010'] = df.HSD010.replace({7: 3})

#ALQ130: numero bebida alcoholica los ultimos 12 meses CAMBIAR
#LIMPIEZA ALQ130 POR ALQ130_Tramos
#reemplazar valores nulos por la media y valores de no contestar por 0
df['ALQ130'] = df.ALQ130.replace({999: 0})
df['ALQ130'] = df.ALQ130.replace({777: 0})
df['ALQ130'] = df['ALQ130'].fillna(3)

#hacer tramos con la frecuencia de toma de bebidas alcoholicas
df.loc[(df['ALQ130'] == 0), 'ALQ130_Tramos'] = int(0)
df.loc[(df['ALQ130'] <= 3) & (df['ALQ130'] >= 1), 'ALQ130_Tramos'] = int(1)
df.loc[(df['ALQ130'] <= 6) & (df['ALQ130'] >= 4), 'ALQ130_Tramos'] = int(2)
df.loc[(df['ALQ130'] <= 10) & (df['ALQ130'] >= 7), 'ALQ130_Tramos'] = int(3)
df.loc[(df['ALQ130'] <= 14) & (df['ALQ130'] >= 11), 'ALQ130_Tramos'] = int(4)
df.loc[(df['ALQ130'] >= 15), 'ALQ130_Tramos'] = int(5)

#DBQ700 
df['DBQ700'] = df.DBQ700.replace({9: 3})
df['DBQ700'] = df.DBQ700.replace({7: 3})
df['DBQ700'] = df['DBQ700'].fillna(3)

#SLQ050 
df['SLQ050'] = df['SLQ050'].fillna(0)
df['SLQ050'] = df.SLQ050.replace({9: 0})
df['SLQ050'] = df.SLQ050.replace({7: 0})
df['SLQ050'] = df.SLQ050.replace({2: 0})


#DPQ020: depresion, con cuanta frecuencia el paciente esta desesperanzado
df['DPQ020'] = df['DPQ020'].fillna(0)
df['DPQ020'] = df['DPQ020'].astype(int, errors = 'raise')
df['DPQ020'] = df.DPQ020.replace({9: 0})
df['DPQ020'] = df.DPQ020.replace({7: 0})

#DPQ030: problemas para dormir o dormir demasiado 
df['DPQ030'] = df['DPQ030'].fillna(0)
df['DPQ030'] = df['DPQ030'].astype(int, errors = 'raise')
df['DPQ030'] = df.DPQ030.replace({9: 0})
df['DPQ030'] = df.DPQ030.replace({7: 0})

#DPQ040: cansado o con poca energía
df['DPQ040'] = df['DPQ040'].fillna(0)
df['DPQ040'] = df['DPQ040'].astype(int, errors = 'raise')
df['DPQ040'] = df.DPQ040.replace({9: 0})
df['DPQ040'] = df.DPQ040.replace({7: 0})

#DPQ050: poco apetito o comer en exceso   
df['DPQ050'] = df['DPQ050'].fillna(0)
df['DPQ050'] = df['DPQ050'].astype(int, errors = 'raise')
df['DPQ050'] = df.DPQ050.replace({9: 0})
df['DPQ050'] = df.DPQ050.replace({7: 0})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:124: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:157: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:175: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:181: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:187: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:230: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:231: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:234: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:236: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:239: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:240: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:242: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:248: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #LIMPIEZA

# %%
#LIMPIEZA DE TODOS LOS CAMPOS FINALIZADA 
#Limpieza DIQ010: el doctor te ha dicho que tienes diabetes (0 no 1 si 2 borderline)
df['DIQ010'] = df['DIQ010'].fillna(0)
df['DIQ010'] = df.DIQ010.replace({9: 0})
df['DIQ010'] = df.DIQ010.replace({7: 0})
df['DIQ010'] = df.DIQ010.replace({2: 0})
df['DIQ010'] = df.DIQ010.replace({3: 2})

#--------------------------------------REQ5 SM
#DIQ070: pastillas para glucosa elevada  0 no 1 si (REQ5)
df['DIQ070'] = df['DIQ070'].fillna(2)
df['DIQ070'] = df.DIQ070.replace({9: 2})
df['DIQ070'] = df.DIQ070.replace({7: 2})
#--------------------------------------REQ5 SM

#INQ020: ingresos salariales en casa
df['INQ020'] = df['INQ020'].fillna(1)
df['INQ020'] = df.INQ020.replace({9: 0})
df['INQ020'] = df.INQ020.replace({7: 0})
df['INQ020'] = df.INQ020.replace({2: 0})

#INDFMMPI: limpieza indice de pobreza de 0 a 4.99 y 5 para 5  o má. 
#Se rellenan los valores con la media 2.1
df['INDFMMPI'] = df['INDFMMPI'].fillna(2.1)
df['INDFMMPI'] = df.INDFMMPI.replace({5.397605e-79: 0})

#INDFMMPC: limpieza cat pobreza con la moda 3
df['INDFMMPC'] = df.INDFMMPC.replace({7: 3})
df['INDFMMPC'] = df.INDFMMPC.replace({9: 3})
df['INDFMMPC'] = df['INDFMMPC'].fillna(3)

#BPXSY1 moda 116
df['BPXSY1']= df['BPXSY1'].fillna(116)

#BPXDI1 moda 68
df['BPXDI1']= df['BPXDI1'].fillna(68)

#BMXWT mediana peso 72.3 en hombres y 62.8 en mujeres
df['BMXWT'][df['RIAGENDR'] == 1] = df['BMXWT'].fillna(72.3)
df['BMXWT'][df['RIAGENDR'] == 2] = df['BMXWT'].fillna(62.8)

#BMXHT mediana altura 169.8 en hombres y 157.4 en mujeres
df['BMXHT'][df['RIAGENDR'] == 1] = df['BMXHT'].fillna(169.8)
df['BMXHT'][df['RIAGENDR'] == 2] = df['BMXHT'].fillna(157.4)

#BMXBMI: moda
df['BMXBMI'][df['RIAGENDR'] == 1] = df['BMXBMI'].fillna(26.6)
df['BMXBMI'][df['RIAGENDR'] == 2] = df['BMXBMI'].fillna(24.5)

#BMXWAIST: moediana 
df['BMXWAIST'][df['RIAGENDR'] == 1] = df['BMXWAIST'].fillna(90.2)
df['BMXWAIST'][df['RIAGENDR'] == 2] = df['BMXWAIST'].fillna(87.1)

#waist height index---------
df.loc[:, 'WHI'] = df['BMXWAIST'] / df['BMXHT']
df['WHI'].isna().sum()
#--------------------

#BPQ030 te han dicho que tienes la presión sanguinea alta más de dos veces
df['BPQ030'] = df['BPQ030'].fillna(0)
df['BPQ030'] = df.BPQ030.replace({2: 0})
df['BPQ030'] = df.BPQ030.replace({7: 0})
df['BPQ030'] = df.BPQ030.replace({9: 0})

#---------------------------------------------------------------
#BPQ040A tomar pastillas para el colesterol HDL bajo (req3 MS)
df['BPQ040A']= df['BPQ040A'].fillna(2)
df['BPQ040A'] = df.BPQ040A.replace({9: 2})

#BPQ050A tomar pastillas para la presión sanguinea elevada (req4 MS)
df['BPQ050A']= df['BPQ050A'].fillna(2)
df['BPQ050A'] = df.BPQ050A.replace({9: 2})

#BPQ090D tomar medicamentos para el colesterol elevado (REQ2 ms)
df['BPQ090D'] = df['BPQ090D'].fillna(2)
df['BPQ090D'] = df.BPQ090D.replace({9: 2})
#--------------------------------------------------------------

#LBXGLU: glucosa en ayunas elevada, se rellena con la moda
df['LBXGLU']= df['LBXGLU'].fillna(99)

#LBXIN: insulina en uU/mL moda 
df['LBXIN']= df['LBXIN'].fillna(6.34)

#MCQ010: el doctor dice que tienes sobrepeso      
df['MCQ010'] = df['MCQ010'].fillna(0)
df['MCQ010'] = df.MCQ010.replace({9: 0})
df['MCQ010'] = df.MCQ010.replace({7: 0})
df['MCQ010'] = df.MCQ010.replace({2: 0})

#MCQ080: el doctor dice que tienes asma     
df['MCQ080'] = df['MCQ080'].fillna(0)
df['MCQ080'] = df.MCQ080.replace({9: 0})
df['MCQ080'] = df.MCQ080.replace({7: 0})
df['MCQ080'] = df.MCQ080.replace({2: 0})

#MCQ220: el doctor dice que tienes cancer alguna vez      
df['MCQ220'] = df['MCQ220'].fillna(0)
df['MCQ220'] = df.MCQ220.replace({9: 0})
df['MCQ220'] = df.MCQ220.replace({7: 0})
df['MCQ220'] = df.MCQ220.replace({2: 0})

#MCQ300C: cerca relativamente a tener diabetes 
df['MCQ300C'] = df['MCQ300C'].fillna(0)
df['MCQ300C'] = df.MCQ300C.replace({9: 0})
df['MCQ300C'] = df.MCQ300C.replace({7: 0})
df['MCQ300C'] = df.MCQ300C.replace({2: 0})

#HIQ011: seguro sanitario   
df['HIQ011'] = df.HIQ011.replace({9: 1})
df['HIQ011'] = df.HIQ011.replace({7: 1})
df['HIQ011'] = df.HIQ011.replace({2: 0})


#LBDHDD: colesterol hdl diferente en mujeres y hombres moda 55 para mujeres y 48 en hombres
df['LBDHDD'][df['RIAGENDR'] == 1] = df['LBDHDD'].fillna(48)
df['LBDHDD'][df['RIAGENDR'] == 2] = df['LBDHDD'].fillna(55)


#SMQ020:ha fumado 100 cigarrillos en su vida    
df['SMQ020'] = df['SMQ020'].fillna(0)
df['SMQ020'] = df.SMQ020.replace({9: 0})
df['SMQ020'] = df.SMQ020.replace({7: 0})
df['SMQ020'] = df.SMQ020.replace({2: 0})


#LBXTR: 89 es la mediana y es el nivel de trigliceridos
df['LBXTR']= df['LBXTR'].fillna(89)

#DMDEDUC2: nivel educativo se trunca a some college
df['DMDEDUC2'] = df.DMDEDUC2.replace({7: 9})
df['DMDEDUC2'] = df.DMDEDUC2.replace({9: 9})
df['DMDEDUC2'] = df['DMDEDUC2'].fillna(9)

#PAQ605
df['PAQ605'] = df['PAQ605'].fillna(0)
df['PAQ605'] = df.PAQ605.replace({9: 0})
df['PAQ605'] = df.PAQ605.replace({7: 0})
df['PAQ605'] = df.PAQ605.replace({2: 0})

#PAQ620     
df['PAQ620'] = df['PAQ620'].fillna(0)
df['PAQ620'] = df.PAQ620.replace({9: 0})
df['PAQ620'] = df.PAQ620.replace({7: 0})
df['PAQ620'] = df.PAQ620.replace({2: 0})

#PAQ635    
df['PAQ635'] = df['PAQ635'].fillna(0)
df['PAQ635'] = df.PAQ635.replace({9: 0})
df['PAQ635'] = df.PAQ635.replace({7: 0})
df['PAQ635'] = df.PAQ635.replace({2: 0})

#PAQ650   
df['PAQ650'] = df['PAQ650'].fillna(0)
df['PAQ650'] = df.PAQ650.replace({9: 0})
df['PAQ650'] = df.PAQ650.replace({7: 0})
df['PAQ650'] = df.PAQ650.replace({2: 0})

#PAQ665      
df['PAQ665'] = df['PAQ665'].fillna(0)
df['PAQ665'] = df.PAQ665.replace({9: 0})
df['PAQ665'] = df.PAQ665.replace({7: 0})
df['PAQ665'] = df.PAQ665.replace({2: 0})

#HSD010: salud del paciente se rellena con buena 3
df['HSD010'] = df['HSD010'].fillna(3)
df['HSD010'] = df.HSD010.replace({9: 3})
df['HSD010'] = df.HSD010.replace({7: 3})

#ALQ130: numero bebida alcoholica los ultimos 12 meses
#LIMPIEZA ALQ130 POR ALQ130_Tramos
#reemplazar valores nulos por la media y valores de no contestar por 0
df['ALQ130'] = df.ALQ130.replace({999: 0})
df['ALQ130'] = df.ALQ130.replace({777: 0})
df['ALQ130'] = df['ALQ130'].fillna(3)

#hacer tramos con la frecuencia de toma de bebidas alcoholicas
df.loc[(df['ALQ130'] == 0), 'ALQ130_Tramos'] = int(0)
df.loc[(df['ALQ130'] <= 3) & (df['ALQ130'] >= 1), 'ALQ130_Tramos'] = int(1)
df.loc[(df['ALQ130'] <= 6) & (df['ALQ130'] >= 4), 'ALQ130_Tramos'] = int(2)
df.loc[(df['ALQ130'] <= 10) & (df['ALQ130'] >= 7), 'ALQ130_Tramos'] = int(3)
df.loc[(df['ALQ130'] <= 14) & (df['ALQ130'] >= 11), 'ALQ130_Tramos'] = int(4)
df.loc[(df['ALQ130'] >= 15), 'ALQ130_Tramos'] = int(5)

#DBQ700 
df['DBQ700'] = df.DBQ700.replace({9: 3})
df['DBQ700'] = df.DBQ700.replace({7: 3})
df['DBQ700'] = df['DBQ700'].fillna(3)

#SLQ050 
df['SLQ050'] = df['SLQ050'].fillna(0)
df['SLQ050'] = df.SLQ050.replace({9: 0})
df['SLQ050'] = df.SLQ050.replace({7: 0})
df['SLQ050'] = df.SLQ050.replace({2: 0})


#DPQ020: depresion, con cuanta frecuencia el paciente esta desesperanzado
df['DPQ020'] = df['DPQ020'].fillna(0)
df['DPQ020'] = df['DPQ020'].astype(int, errors = 'raise')
df['DPQ020'] = df.DPQ020.replace({9: 0})
df['DPQ020'] = df.DPQ020.replace({7: 0})

#DPQ030: problemas para dormir o dormir demasiado 
df['DPQ030'] = df['DPQ030'].fillna(0)
df['DPQ030'] = df['DPQ030'].astype(int, errors = 'raise')
df['DPQ030'] = df.DPQ030.replace({9: 0})
df['DPQ030'] = df.DPQ030.replace({7: 0})

#DPQ040: cansado o con poca energía
df['DPQ040'] = df['DPQ040'].fillna(0)
df['DPQ040'] = df['DPQ040'].astype(int, errors = 'raise')
df['DPQ040'] = df.DPQ040.replace({9: 0})
df['DPQ040'] = df.DPQ040.replace({7: 0})

#DPQ050: poco apetito o comer en exceso   
df['DPQ050'] = df['DPQ050'].fillna(0)
df['DPQ050'] = df['DPQ050'].astype(int, errors = 'raise')
df['DPQ050'] = df.DPQ050.replace({9: 0})
df['DPQ050'] = df.DPQ050.replace({7: 0})

# %% [markdown]
# #CALCULO DE PREVALENCIA DEL SINDROME METABOLICO

# %%
#CONDICIONES DE SINDROME METABOLICO
#CONDICIONES Y AÑADIR FILAS DE REQUISITOS

#CONDICION REQUISITO 1

condiciones_REQ1 = [((df['RIAGENDR'] == 2) & (df['BMXWAIST']>= 102)) | ((df['RIAGENDR'] == 1) & (df['BMXWAIST']>= 88)),
                     ((df['RIAGENDR'] == 2) & (df['BMXWAIST']< 102)) | ((df['RIAGENDR'] == 1) & (df['BMXWAIST']< 88)),
                    ]
                                                  
opciones_REQ1 = [1, 0]

df['REQ1'] = np.select(condiciones_REQ1, opciones_REQ1)


#CONDICION REQUISITO 2

condiciones_REQ2 = [(df['LBXTR'] >= 150) | (df['BPQ090D'] == 1),
                     (df['LBXTR'] < 150) | (df['BPQ090D'] == 2) 
                    ]
                                                  
opciones_REQ2 = [1, 0]

df['REQ2'] = np.select(condiciones_REQ2, opciones_REQ2)

#CONDICION REQUISITO 3

condiciones_REQ3 = [((df['RIAGENDR'] == 2) & (df['LBDHDD']<= 50 )) | ((df['RIAGENDR'] == 1) & (df['LBDHDD'] <= 40)) | (df['BPQ040A'] == 1) ,
                     ((df['RIAGENDR'] == 2) & (df['LBDHDD']> 50)) | ((df['RIAGENDR'] == 1) & (df['LBDHDD'] > 40)) | (df['BPQ040A'] == 2),
                    ]
                                                  
opciones_REQ3 = [1, 0]

df['REQ3'] = np.select(condiciones_REQ3, opciones_REQ3)



#CONDICION REQUISITO 4


condiciones_REQ4 = [(df['BPXSY1'] >= 130) | (df['BPXDI1'] >= 85) | (df['BPQ050A'] == 1),
                     (df['BPXSY1'] < 130) | (df['BPXDI1'] < 85) | (df['BPQ050A'] == 2)
                    ]
                                                  
opciones_REQ4 = [1, 0]

df['REQ4'] = np.select(condiciones_REQ4, opciones_REQ4)

#CONDICION REQUISITO 5

condiciones_REQ5 = [(df['LBXGLU'] >= 100) | (df['DIQ070'] == 1),
                     (df['LBXGLU'] < 100) | (df['DIQ070'] == 2)
                    ]
                                                  
opciones_REQ5 = [1, 0]

df['REQ5'] = np.select(condiciones_REQ5, opciones_REQ5)

#SUMA DE REQUISITOS POR FILA
df['REQ_SUM'] = df['REQ1'] + df['REQ2'] + df['REQ3'] + df['REQ4'] + df['REQ5']

#ENCODING METSYM 1 ES QUE TIENE Y 0 ES QUE NO
condiciones_METSYM = [(df['REQ_SUM'] >= 3),
                     (df['REQ_SUM'] < 3)
                    ]
                                                  
opciones_METSYM = [1, 0]

df['MET_SYM'] = np.select(condiciones_METSYM, opciones_METSYM)

# %% [markdown]
# #PORCENTAJE Y EXPORT

# %%
#PREVALENCIA EN PORCENTAJE

#porcentaje de los que presentan sindrome metabolico
porcentaje_METSYM_1112 = 100 * df['MET_SYM'].value_counts() / len(df['MET_SYM'])
#conteo de valores
df['MET_SYM'].value_counts()
print("porcentaje SM: ", porcentaje_METSYM_1112)
#df.to_csv('df.csv')
# Out:
# porcentaje SM:  0    70.092538
# 1    29.907462
# Name: MET_SYM, dtype: float64

# %%
df.isna().sum()
# Out:
# SEQN             0
# DIQ010           0
# DIQ070           0
# INQ020           0
# INDFMMPI         0
# INDFMMPC         0
# BPXSY1           0
# BPXDI1           0
# BMXWT            0
# BMXHT            0
# BMXBMI           0
# BMXWAIST         0
# BPQ030           0
# BPQ040A          0
# BPQ050A          0
# BPQ090D          0
# LBXGLU           0
# LBXIN            0
# MCQ010           0
# MCQ080           0
# MCQ220           0
# MCQ300C          0
# HIQ011           0
# LBDHDD           0
# SMQ020           0
# LBXTR            0
# RIAGENDR         0
# RIDAGEYR         0
# RIDRETH3         0
# DMDEDUC2         0
# PAQ605           0
# PAQ620           0
# PAQ635           0
# PAQ650           0
# PAQ665           0
# HSD010           0
# ALQ130           0
# DBQ700           0
# SLQ050           0
# DPQ020           0
# DPQ030           0
# DPQ040           0
# DPQ050           0
# WHI              0
# ALQ130_Tramos    0
# REQ1             0
# REQ2             0
# REQ3             0
# REQ4             0
# REQ5             0
# REQ_SUM          0
# MET_SYM          0
# dtype: int64

# %%
#EXPORT
df.to_csv('df_procesado.csv')

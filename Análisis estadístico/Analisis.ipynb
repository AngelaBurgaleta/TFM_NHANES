# %%
#imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 


url_df = 'https://raw.githubusercontent.com/AngelaBurgaleta/TFM_NHANES/main/DATASETS%20DEFINITIVOS/PROCESSED/df_procesado_genderandage.csv'
url_df45_sinoutliers = 'https://raw.githubusercontent.com/AngelaBurgaleta/TFM_NHANES/main/DATASETS%20DEFINITIVOS/PROCESSED/Sin_outliers/df_v45sinoutliers.csv'
df = pd.read_csv(url_df45_sinoutliers)
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
#descarto personas menores de 12 años

Delete_index = df[df['RIDAGEYR'] <= 12 ].index
df_v2 = df.drop(Delete_index)

# %%
vars_drop = ['SEQN', 'REQ1', 'REQ2', 'REQ3', 'REQ4', ]

# %%
df.shape
# Out:
# (26865, 59)

# %%
df.isna().sum()
# Out:
# SEQN               0
# DIQ010             0
# DIQ070             0
# INQ020             0
# INDFMMPI           0
# INDFMMPC           0
# BPXSY1             0
# BPXDI1             0
# BMXWT              0
# BMXHT              0
# BMXBMI             0
# BMXWAIST           0
# BPQ030             0
# BPQ040A            0
# BPQ050A            0
# BPQ090D            0
# LBXGLU             0
# LBXIN              0
# MCQ010             0
# MCQ080             0
# MCQ220             0
# MCQ300C            0
# HIQ011             0
# LBDHDD             0
# SMQ020             0
# LBXTR              0
# RIAGENDR           0
# RIDAGEYR           0
# RIDRETH3           0
# DMDEDUC2           0
# PAQ605             0
# PAQ620             0
# PAQ635             0
# PAQ650             0
# PAQ665             0
# HSD010             0
# ALQ130             0
# DBQ700             0
# SLQ050             0
# DPQ020             0
# DPQ030             0
# DPQ040             0
# DPQ050             0
# ...

# %% [markdown]
# #Analisis general, qué tipo de participantes nos encontramos en el dataset. En cuanto a condiciones demograficas
#
# distribucion participantes por genero
# distribucion participantes por raza
# distribucion de participantes por edad
# distribucion bmi y whi
#
# distribucion por requisitos
# sindrome metabolico

# %%
#DISTRIBUCION DE PARTICIPANTES POR GENERO

#pastel, dark, bright, inferno, mute
#sns.catplot(x = "RIAGENDR", y = "SEQN", kind = "bar", data = df, ci = 30);


porcentaje_genero= 100 * df['Género'].value_counts() / len(df['Género'])
total_valores_genero = df['Género'].value_counts()

#df = df.rename(columns={'RIAGENDR':'Género'})
df['Género'] = df.Género.replace({1: "Hombre"})
df['Género'] = df.Género.replace({2: "Mujer"})

plt.figure(figsize = (6,7))
print('porcentaje = \n', porcentaje_genero)
print('\n')
print('total valores = \n', total_valores_genero)
print('\n')
sns.countplot(data=df, x= 'Género')

'''
g = sns.catplot(x="DPQ020", hue="RIAGENDR", col="MET_SYM",
                data=df, kind="count", palette='bright',
                height=4, aspect=.7)

'''
# Out:
# porcentaje =
#  2.0    51.070166
# 1.0    48.929834
# Name: Género, dtype: float64
#
#
# total valores =
#  2.0    13720
# 1.0    13145
# Name: Género, dtype: int64
# '\ng = sns.catplot(x="DPQ020", hue="RIAGENDR", col="MET_SYM",\n                data=df, kind="count", palette=\'bright\',\n                height=4, aspect=.7)\n\n'

# %%
#DISTRIBUCION DE PARTICIPANTES POR GENERO

#pastel, dark, bright, inferno, mute
#sns.catplot(x = "RIAGENDR", y = "SEQN", kind = "bar", data = df, ci = 30);
df_MS = df_MS.rename(columns={'RIAGENDR':'Género'})

porcentaje_genero= 100 * df_MS['Género'].value_counts() / len(df_MS['Género'])
total_valores_genero = df_MS['Género'].value_counts()


df_MS['Género'] = df_MS.Género.replace({1: "Hombre"})
df_MS['Género'] = df_MS.Género.replace({2: "Mujer"})

plt.figure(figsize = (6,7))
print('porcentaje = \n', porcentaje_genero)
print('\n')
print('total valores = \n', total_valores_genero)
print('\n')
sns.countplot(data=df_MS, x= 'Género')

'''
g = sns.catplot(x="DPQ020", hue="RIAGENDR", col="MET_SYM",
                data=df, kind="count", palette='bright',
                height=4, aspect=.7)

'''
# Out:
# porcentaje =
#  1.0    56.847963
# 2.0    43.152037
# Name: Género, dtype: float64
#
#
# total valores =
#  1.0    6334
# 2.0    4808
# Name: Género, dtype: int64
# '\ng = sns.catplot(x="DPQ020", hue="RIAGENDR", col="MET_SYM",\n                data=df, kind="count", palette=\'bright\',\n                height=4, aspect=.7)\n\n'

# %%
#Distribucion de participantes por tramos de edad
porcentaje_genero= 100 * df['RIDAGEYR_Tramos'].value_counts() / len(df['RIDAGEYR_Tramos'])
total_valores_genero = df['RIDAGEYR_Tramos'].value_counts()

plt.figure(figsize = (15,8))

print('porcentaje = \n', porcentaje_genero)
print('\n')
print('total valores = \n', total_valores_genero)
print('\n')
sns.countplot(data=df, x= 'RIDAGEYR_Tramos')
# Out:
# porcentaje =
#  6.0    21.832179
# 4.0    20.937086
# 5.0    20.447178
# 7.0    18.671725
# 3.0    18.111831
# Name: RIDAGEYR_Tramos, dtype: float64
#
#
# total valores =
#  6.0    5927
# 4.0    5684
# 5.0    5551
# 7.0    5069
# 3.0    4917
# Name: RIDAGEYR_Tramos, dtype: int64

# %%
#Distribución por tramos de edad


plt.figure(figsize = (20,10))

data = df['RIDAGEYR_Tramos'].value_counts()

labels = ['De 12 a 20', 'De 20 a 35', 'De 35 a 50', 'De 50 a 65', 'De 65 a 80']
colors = sns.color_palette('pastel')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.show()

# %%
#Distribucion de participantes por EDAD
porcentaje_genero= 100 * df['RIDAGEYR'].value_counts() / len(df['RIDAGEYR'])
total_valores_genero = df['RIDAGEYR'].value_counts()

plt.figure(figsize = (15,8))
sns.histplot(data=df, x= 'RIDAGEYR')

# %%
df['RIDRETH3'].unique()
# Out:
# array([3., 1., 6., 4., 7., 2.])

# %%
df['RIDRETH3'].value_counts()
# Out:
# 3.0    12331
# 4.0     8883
# 1.0     6026
# 6.0     4491
# 2.0     3984
# 7.0     1891
# Name: RIDRETH3, dtype: int64

# %%
#Distribución por etnia


plt.figure(figsize = (20,10))


data = df['RIDRETH3'].value_counts()

labels = ['Blanco no hispano', 'Negro no hispano', 'Mexicano americano', 'Asiático no hispano', 'Otro tipo hispano', 'Otra raza']
colors = sns.color_palette('Set2')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.show()

# %% [markdown]
# #Prevalencia síndrome metabólico

# %%
#PREVALENCIA EN PORCENTAJE ELIMINANDO LOS DOS PRIMEROS GRUPOS DE EDAD
#Distribución por tramos de edad




#porcentaje de los que presentan sindrome metabolico
porcentaje_METSYM_v2 = 100 * df_v2['MET_SYM'].value_counts() / len(df_v2['MET_SYM'])
print(porcentaje_METSYM_v2)
#conteo de valores
df['MET_SYM'].value_counts()

plt.figure(figsize = (20,10))

data = df_MS['RIDAGEYR_Tramos'].value_counts()

labels = ['De 65 a 80', 'De 50 a 65', 'De 35 a 50', 'De 20 a 35', 'De 12 a 20']
colors = sns.color_palette('pastel')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.show()
# Out:
# 0    58.525963
# 1    41.474037
# Name: MET_SYM, dtype: float64

# %%
#PREVALENCIA EN PORCENTAJE

#porcentaje de los que presentan sindrome metabolico
porcentaje_METSYM_1112 = 100 * df['MET_SYM'].value_counts() / len(df['MET_SYM'])
print(porcentaje_METSYM_1112)
#conteo de valores
df['MET_SYM'].value_counts()
# Out:
# 0    58.525963
# 1    41.474037
# Name: MET_SYM, dtype: float64
# 0    15723
# 1    11142
# Name: MET_SYM, dtype: int64

# %%
#POR SINDROME METABOLICO

porcentaje_genero= 100 * df['MET_SYM'].value_counts() / len(df['MET_SYM'])
total_valores_genero = df['MET_SYM'].value_counts()

print('porcentaje = \n', porcentaje_genero)
print('\n')
print('total valores = \n', total_valores_genero)
print('\n')
sns.countplot(data=df, x= 'MET_SYM')
# Out:
# porcentaje =
#  0    58.525963
# 1    41.474037
# Name: MET_SYM, dtype: float64
#
#
# total valores =
#  0    15723
# 1    11142
# Name: MET_SYM, dtype: int64

# %%
#sINDROME METABOLICO POR EDUCACION 
df_MS['DMDEDUC2'] = df_MS.DMDEDUC2.replace({1: "Menos de 9º grado"})
df_MS['DMDEDUC2'] = df_MS.DMDEDUC2.replace({2: "9º-11º grado "})
df_MS['DMDEDUC2'] = df_MS.DMDEDUC2.replace({3: "Graduado de secundaria "})
df_MS['DMDEDUC2'] = df_MS.DMDEDUC2.replace({4: "Educación superior"})
df_MS['DMDEDUC2'] = df_MS.DMDEDUC2.replace({5: "Grado universitario o superior"})
df_MS['DMDEDUC2'] = df_MS.DMDEDUC2.replace({7: "Se niega a responder"})
plt.figure(figsize = (15,8))
sns.countplot(data=df_MS, x= 'DMDEDUC2')

# %%
url_df = 'https://raw.githubusercontent.com/AngelaBurgaleta/TFM_NHANES/main/DATASETS%20DEFINITIVOS/PROCESSED/df_procesado_genderandage.csv'
url_df45_sinoutliers = 'https://raw.githubusercontent.com/AngelaBurgaleta/TFM_NHANES/main/DATASETS%20DEFINITIVOS/PROCESSED/Sin_outliers/df_v45sinoutliers.csv'
df = pd.read_csv(url_df45_sinoutliers)
df = df.drop(['Unnamed: 0'], axis = 1)


#sINDROME METABOLICO POR fumador
df['SMQ020'] = df.SMQ020.replace({0: "No fumador"})
df['SMQ020'] = df.SMQ020.replace({1: "Sí fumador"})
df['MET_SYM'] = df.MET_SYM.replace({1: "Presenta SM"})
df['MET_SYM'] = df.MET_SYM.replace({0: "No presenta SM"})

plt.figure(figsize = (15,8))


sns.catplot(x="MET_SYM", hue="SMQ020", 
                data=df, kind="count", palette='bright',
                height=7, aspect=1.3)

# %%
#sINDROME METABOLICO POR ETNIA
url_df = 'https://raw.githubusercontent.com/AngelaBurgaleta/TFM_NHANES/main/DATASETS%20DEFINITIVOS/PROCESSED/df_procesado_genderandage.csv'
url_df45_sinoutliers = 'https://raw.githubusercontent.com/AngelaBurgaleta/TFM_NHANES/main/DATASETS%20DEFINITIVOS/PROCESSED/Sin_outliers/df_v45sinoutliers.csv'
df = pd.read_csv(url_df45_sinoutliers)
df = df.drop(['Unnamed: 0'], axis = 1)

df_MS = df[df['MET_SYM'] == 1]

#Distribución por etnia


plt.figure(figsize = (20,10))

data = df_MS['RIDRETH3'].value_counts()

labels = ['Blanco no hispano', 'Negro no hispano', 'Mexicano americano', 'Asiático no hispano', 'Otro tipo hispano', 'Otra raza']

colors = sns.color_palette('pastel')
plt.pie(data, labels=labels,colors = colors, autopct = '%0.0f%%')
plt.show()

# %%
df_MS = df[df['MET_SYM'] == 1]
df_MS['RIDAGEYR_Tramos'] = df.RIDAGEYR_Tramos.replace({2.0: np.nan})
df_MS['RIDAGEYR_Tramos'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 7.0    4087
# 6.0    4041
# 5.0    2144
# 4.0     774
# 3.0     193
# Name: RIDAGEYR_Tramos, dtype: int64

# %%
#histograma de requisitos de todo el dataset

print(df['REQ1'].value_counts())

print(df['REQ2'].value_counts())

print(df['REQ3'].value_counts())


print(df['REQ4'].value_counts())


print(df['REQ5'].value_counts())

reqs = [13953, 7464, 14075, 10542, 13798]
labels = ['REQ1', 'REQ2', 'REQ3', 'REQ4', 'REQ5']
plt.figure(figsize = (20,10))

colors = sns.color_palette("husl", 5)
plt.pie(reqs, labels=labels,colors = colors, autopct = '%0.0f%%')
# Out:
# 1    13706
# 0    13442
# Name: REQ1, dtype: int64
# 0    19703
# 1     7445
# Name: REQ2, dtype: int64
# 0    14163
# 1    12985
# Name: REQ3, dtype: int64
# 0    16624
# 1    10524
# Name: REQ4, dtype: int64
# 1    13728
# 0    13420
# Name: REQ5, dtype: int64
# ([<matplotlib.patches.Wedge at 0x7fb9a47ec310>,
# ...
#  [Text(0.8177606987449739, 0.7357088008092144, 'REQ1'),
#   Text(-0.31072183893975497, 1.0552023212663517, 'REQ2'),
#   Text(-1.0870699371679418, 0.16816346721475336, 'REQ3'),
#   Text(-0.460268734070435, -0.9990759192559889, 'REQ4'),
#   Text(0.8237211208787556, -0.7290291592373015, 'REQ5')],
#  [Text(0.44605129022453116, 0.4012957095322987, '23%'),
#   Text(-0.1694846394216845, 0.5755649025089191, '12%'),
#   Text(-0.5929472384552409, 0.09172552757168365, '24%'),
#   Text(-0.25105567312932814, -0.5449505014123576, '18%'),
#   Text(0.44930242957023026, -0.39765226867489173, '23%')])

# %%
#sINDROME METABOLICO POR SEXO 

sns.catplot(x="MET_SYM", hue="SMQ020", 
                data=df, kind="count", palette='bright',
                height=7, aspect=1.3)

# %%
#Porcentaje y export
#PREVALENCIA EN PORCENTAJE de fumadores
df_smk = df[df['MET_SYM'] == 1]

df_smk['SMQ020'].value_counts() / len(df_smk)

#porcentaje de los que presentan sindrome metabolico
#porcentaje_METSYM_1112 = 100 * df['SMQ020'].value_counts() / len(df['MET_SYM'])
#conteo de valores
#df['MET_SYM'].value_counts()
#print("porcentaje SM: ", porcentaje_METSYM_1112)
#df.to_csv('df.csv')
# Out:
# 0.0    0.515796
# 1.0    0.484204
# Name: SMQ020, dtype: float64

# %%
#histograma de requisitos para los que tienen SM
df_MS = df[df['MET_SYM'] == 1]
print(df_MS['REQ1'].value_counts())

print(df_MS['REQ2'].value_counts())

print(df_MS['REQ3'].value_counts())


print(df_MS['REQ4'].value_counts())


print(df_MS['REQ5'].value_counts())

reqs = [8838, 6623, 9392, 8899, 9823]
labels = ['REQ1', 'REQ2', 'REQ3', 'REQ4', 'REQ5']
plt.figure(figsize = (20,10))

colors = sns.color_palette('pastel')
plt.pie(reqs, labels=labels,colors = colors, autopct = '%0.0f%%')
# Out:
# 1    8834
# 0    2405
# Name: REQ1, dtype: int64
# 1    6616
# 0    4623
# Name: REQ2, dtype: int64
# 1    9385
# 0    1854
# Name: REQ3, dtype: int64
# 1    8899
# 0    2340
# Name: REQ4, dtype: int64
# 1    9815
# 0    1424
# Name: REQ5, dtype: int64
# ([<matplotlib.patches.Wedge at 0x7fb9a474bbd0>,
# ...
#  [Text(0.8841501666212477, 0.654429891480837, 'REQ1'),
#   Text(-0.19808997691200525, 1.0820168025714765, 'REQ2'),
#   Text(-1.0697386655766212, 0.25624048737533583, 'REQ3'),
#   Text(-0.5149593867249408, -0.9720168877256573, 'REQ4'),
#   Text(0.8354864716421369, -0.715515447564183, 'REQ5')],
#  [Text(0.48226372724795324, 0.3569617589895474, '20%'),
#   Text(-0.10804907831563922, 0.5901909832208052, '15%'),
#   Text(-0.5834938175872479, 0.13976753856836496, '22%'),
#   Text(-0.28088693821360405, -0.5301910296685403, '20%'),
#   Text(0.4557198936229837, -0.390281153216827, '23%')])

# %% [markdown]
# ##REGRESION LOGISTICA POR EDAD Y SEXO

# %%
import statsmodels.api as sm
model = sm.OLS.from_formula("MET_SYM ~ RIDAGEYR", df)
result = model.fit()
result.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                MET_SYM   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.446
# Method:                 Least Squares   F-statistic:                 3.027e+04
# Date:                Mon, 02 May 2022   Prob (F-statistic):               0.00
# Time:                        08:08:45   Log-Likelihood:                -12879.
# No. Observations:               37606   AIC:                         2.576e+04
# Df Residuals:                   37604   BIC:                         2.578e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
model = sm.OLS.from_formula("MET_SYM ~ RIAGENDR", df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                MET_SYM   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     352.4
# Date:                Mon, 02 May 2022   Prob (F-statistic):           2.88e-78
# Time:                        08:09:41   Log-Likelihood:                -23807.
# No. Observations:               37606   AIC:                         4.762e+04
# Df Residuals:                   37604   BIC:                         4.764e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4321      0.007     57.889      0.000       0.417       0.447
# ...

# %%
model = sm.OLS.from_formula("MET_SYM ~ RIDAGEYR + RIAGENDR", df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                MET_SYM   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                 1.586e+04
# Date:                Mon, 02 May 2022   Prob (F-statistic):               0.00
# Time:                        08:11:23   Log-Likelihood:                -12481.
# No. Observations:               37606   AIC:                         2.497e+04
# Df Residuals:                   37603   BIC:                         2.499e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0267      0.006      4.457      0.000       0.015       0.038
# ...

# %% [markdown]
# ##BOXPLOT DE REQUISITOS

# %%
#PERIMETRO ABDOMINAL
#Presión sanguínea
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize = (20, 10))
#df = sns.load_dataset("df")

ax = sns.boxplot(data = df, orient = 'h', x=df["BMXWAIST"], y = df['RIDAGEYR_Tramos'], palette="Set2")

# %%
#indice cintura altura 

sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize = (20, 10))
#df = sns.load_dataset("df")
ax = sns.boxplot(data = df, orient = 'h', x=df["WHI"], y = df['RIDAGEYR_Tramos'], palette="Set2")

# %%
#IMC

sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize = (20, 10))
#df = sns.load_dataset("df")
ax = sns.boxplot(data = df, orient = 'h', x=df["BMXBMI"], y = df['RIDAGEYR_Tramos'], palette="Set2")

# %%
#SOBREPESO Y OBESIDAD POR CINTURA ALTURA
df_male = df[df['RIAGENDR'] == 1]
df_female = df[df['RIAGENDR'] == 2]

df_male_sobrepeso = df_male[(df_male['WHI'] > 0.52) & (df_male['WHI'] <= 0.57)]
df_male_sobrepesoe = df_male[(df_male['WHI'] > 0.57) & (df_male['WHI'] <= 0.62)]
df_male_obesidad = df_male[(df_male['WHI'] > 0.62)]

df_female_sobrepeso = df_female[(df_female['WHI'] > 0.49) & (df_female['WHI'] <= 0.53)]
df_female_sobrepesoe = df_female[(df_female['WHI'] > 0.53) & (df_female['WHI'] <= 0.57)]
df_female_obesidad = df_female[(df_female['WHI'] > 0.58)]

print( len(df_male_sobrepeso) / len(df_male) )
print(len(df_male_sobrepesoe) / len(df_male) )
print(len(df_male_obesidad) / len(df_male) )
print('/n')
print( len(df_female_sobrepeso) / len(df_female) )
print(len(df_female_sobrepesoe) / len(df_female) )
print(len(df_female_obesidad) / len(df_female) )
# Out:
# 0.20738163666616247
# 0.22598699137800635
# 0.25374376039933444
# /n
# 0.12329455694384604
# 0.13464024127531238
# 0.5446646560390637

# %%
df_male_sobrepeso = df_male[(df_male['WHI'] > 0.52) & (df_male['WHI'] <= 0.57)]
df_male_sobrepesoe = df_male[(df_male['WHI'] > 0.57) & (df_male['WHI'] <= 0.62)]
df_male_obesidad = df_male[(df_male['WHI'] > 0.62)]

df_female_sobrepeso = df_female[(df_female['WHI'] > 0.49) & (df_female['WHI'] <= 0.53)]
df_female_sobrepesoe = df_female[(df_female['WHI'] > 0.53) & (df_female['WHI'] <= 0.57)]
df_female_obesidad = df_female[(df_female['WHI'] > 0.57)]

# %%
#SOBREPESO Y OBESIDAD POR IMC
df_male = df[df['RIAGENDR'] == 1]
df_female = df[df['RIAGENDR'] == 2]

df_male_sobrepeso = df_male[(df_male['WHI'] > 0.52) & (df_male['WHI'] <= 0.57)]
df_male_sobrepesoe = df_male[(df_male['WHI'] > 0.57) & (df_male['WHI'] <= 0.62)]
df_male_obesidad = df_male[(df_male['WHI'] > 0.62)]

df_female_sobrepeso = df_female[(df_female['WHI'] > 0.49) & (df_female['WHI'] <= 0.53)]
df_female_sobrepesoe = df_female[(df_female['WHI'] > 0.53) & (df_female['WHI'] <= 0.57)]
df_female_obesidad = df_female[(df_female['WHI'] > 0.57)]

# %%
len(df_male_sobrepeso)
# Out:
# 2742

# %%
df_v2.shape
# Out:
# (27148, 59)

# %%
#Presión sanguínea
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize = (20, 10))
#df = sns.load_dataset("df")
ax = sns.boxplot(data = df, orient = 'h', x=df["BPXSY1"], y = df['RIDAGEYR_Tramos'], palette="Set2")

# %%
df['BPXDI1'].describe()
# Out:
# count    3.760600e+04
# mean     6.700500e+01
# std      1.296579e+01
# min      5.397605e-79
# 25%      6.200000e+01
# 50%      6.800000e+01
# 75%      7.200000e+01
# max      1.360000e+02
# Name: BPXDI1, dtype: float64

# %%
#Presión sanguínea
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize = (20, 10))
#df = sns.load_dataset("df")
ax = sns.boxplot(data = df, orient = 'h', x=df["BPXDI1"], y = df['RIDAGEYR_Tramos'], palette="Set2")

# %% [markdown]
# #Matriz de correlación

# %%
vars_sm = ['REQ1', 'REQ2', 'REQ3', 'REQ4', 'REQ5', 'BMXWAIST', 'LBXTR', 'BPQ090D', 'BPXSY1', 'BPXDI1', 'BPQ050A', 'LBXGLU', 'DIQ070']
vars_aux = ['SEQN', 'BMXWT', 'BMXHT', 'REQ_SUM']
df_corr = df.drop(['REQ1', 'REQ2', 'REQ3', 'REQ4', 'REQ5', 'BMXWAIST', 'LBXTR', 'BPQ090D', 'BPXSY1', 'BPXDI1', 'BPQ050A', 'LBXGLU', 'DIQ070'], axis = 1)
df_corr = df_corr.drop(['SEQN', 'BMXWT', 'BMXHT', 'REQ_SUM'], axis = 1)

# %%
df_v2corr = df.drop(['REQ1', 'REQ2', 'REQ3', 'REQ4', 'REQ5', 'BMXWAIST', 'LBXTR', 'BPQ090D', 'BPXSY1', 'BPXDI1', 'BPQ050A', 'LBXGLU', 'DIQ070', 'SEQN', 'BMXWT', 'BMXHT', 'REQ_SUM' ], axis = 1)

# %%
df_corr.shape
# Out:
# (26865, 42)

# %%
df_corr.isna().sum()
# Out:
# DIQ010             0
# INQ020             0
# INDFMMPI           0
# INDFMMPC           0
# BMXBMI             0
# BPQ030             0
# BPQ040A            0
# LBXIN              0
# MCQ010             0
# MCQ080             0
# MCQ220             0
# MCQ300C            0
# HIQ011             0
# LBDHDD             0
# SMQ020             0
# RIAGENDR           0
# RIDAGEYR           0
# RIDRETH3           0
# DMDEDUC2           0
# PAQ605             0
# PAQ620             0
# PAQ635             0
# PAQ650             0
# PAQ665             0
# HSD010             0
# ALQ130             0
# DBQ700             0
# SLQ050             0
# DPQ020             0
# DPQ030             0
# DPQ040             0
# DPQ050             0
# RIDAGEYR_Tramos    0
# Etnia_1.0          0
# Etnia_2.0          0
# Etnia_3.0          0
# Etnia_4.0          0
# Etnia_6.0          0
# Etnia_7.0          0
# WHI                0
# ALQ130_Tramos      0
# MET_SYM            0
# dtype: int64

# %%
## Correlation

#get correlations of each features in dataset
corrmat =df_corr.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corr[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#correlacion por etnia
vars_etnia = ['MET_SYM', 'Etnia_1.0', 'Etnia_2.0', 'Etnia_3.0', 'Etnia_4.0', 'Etnia_6.0', 'Etnia_7.0' ]
df_corretnia = df_corr[vars_etnia]

#get correlations of each features in dataset
corrmat =df_corretnia.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corretnia[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#correlacion ejercicio

vars_ejercicio = ['PAQ605', 'PAQ620', 'PAQ635', 'PAQ650', 'PAQ665', 'MET_SYM']
df_correjercicio = df_corr[vars_ejercicio]


## Correlation

#get correlations of each features in dataset
corrmat =df_correjercicio.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_correjercicio[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#CORRELACION ALCOHOL Y TABACO 

vars_alq = ['MET_SYM', 'SMQ020', 'ALQ130', 'ALQ130_Tramos']
df_corralq = df_corr[vars_alq]


#get correlations of each features in dataset
corrmat =df_corralq.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corralq[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#correlacion preguntas del doctor sobre sobrepeso, asma, cancer y diabetes

vars_mcq = ['MCQ080', 'MCQ010', 'MCQ220', 'MCQ300C', 'DIQ010', 'MET_SYM']
df_corrmcq = df_corr[vars_mcq]

#todas tienen relacion menos la de asma 

#get correlations of each features in dataset
corrmat =df_corrmcq.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corrmcq[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#problemas durmiendo y de depresion



vars_dpq = ['DPQ020', 'DPQ030', 'DPQ040', 'DPQ050', 'SLQ050', 'MET_SYM']
#feeling down depressed hopeless, trouble sleeping or too much, sentirse cansado, poor appetite overeatin, alguna vez has dicho al doc que tienes probleamas para dormir
df_corrdpq = df_corr[vars_dpq]

#todas tienen relacion menos la de asma 

#get correlations of each features in dataset
corrmat =df_corrdpq.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corrdpq[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df['SLQ050'].unique()
# Out:
# array([0., 1.])

# %%
#dinero

vars_inq = ['INQ020', 'INDFMMPI', 'INDFMMPC',  'HIQ011', 'MET_SYM']
df_corrinq = df_corr[vars_inq]
#income from salary, indice de pobreza familiar menusal, categoria nivel de pobreza, tener un seguro de salud
#get correlations of each features in dataset
corrmat =df_corrinq.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corrinq[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df_inq020 = df[df['MET_SYM'] == 1]

df_inq020['SMQ020'].value_counts() / len(df_inq020)
# Out:
# 0.0    0.515796
# 1.0    0.484204
# Name: SMQ020, dtype: float64

# %%
#CONDICION DIETA GENERAL

vars_health = ['MET_SYM', 'HSD010', 'DBQ700']
df_corrhealth = df_corr[vars_health]

#get correlations of each features in dataset
corrmat =df_corrhealth.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corrhealth[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#CORRELACION POR VARIABLES DEMOGRAFICAS

#CONDICION DIETA GENERAL

vars_demo = ['MET_SYM', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEYR_Tramos', 'RIDRETH3', 'DMDEDUC2']
df_corrdemo = df_corr[vars_demo]

#get correlations of each features in dataset
corrmat =df_corrdemo.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df_corrdemo[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
#Descarte de variables pre PCA


vars_descarte = ['DPQ050', 'MCQ010', 'DBQ700', 'ALQ130', 'ALQ130_Tramos', 'PAQ665', 'PAQ620', 'PAQ605']
